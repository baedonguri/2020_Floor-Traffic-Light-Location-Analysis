# %%
import urllib.request
import json
from bs4 import BeautifulSoup
import pandas as pd



def default_text(node, text):
    if node != None:
        return node.text.strip()
    else:
        return text
    
    
# key = '8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D'
# url = 'http://apis.data.go.kr/B552061/jaywalking/getRestJaywalking?ServiceKey=8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D&searchYearCd=2017&siDo=11&guGun=680&type=json&numOfRows=10&pageNo=1'
url = 'http://apis.data.go.kr/B552061/jaywalking/getRestJaywalking?ServiceKey=8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D&searchYearCd=2017&siDo=28&guGun=260&numOfRows=10&pageNo=1'
res = requests.get(url)
text = res.text
# print(text)

soup = BeautifulSoup(text, 'lxml-xml')

items = soup.select('response > body > items > item')
l = []

for item in items:
    print(item.select_one('spot_nm').text,
         item.select_one('occrrnc_cnt').text,
         item.select_one('lo_crd').text,
         item.select_one('la_crd').text)
    store1.append([item.select_one('spot_nm').text, 
              item.select_one('occrrnc_cnt').text,
                  item.select_one('lo_crd'),
                  item.select_one('la_crd')])


# df = pd.DataFrame(l, columns = ['Location', 'count'])

# df.to_csv('C:/PYTHON/api_test.csv', index=False, encoding='cp949')
# Out:
# 인천광역시 서구 심곡동(신성악기 부근) 4 126.672502179433 37.542273921305

# %%
import urllib.request
import json
from bs4 import BeautifulSoup
import pandas as pd



def default_text(node, text):
    if node != None:
        return node.text.strip()
    else:
        return text
    
    
# key = '8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D'
# url = 'http://apis.data.go.kr/B552061/jaywalking/getRestJaywalking?ServiceKey=8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D&searchYearCd=2017&siDo=11&guGun=680&type=json&numOfRows=10&pageNo=1'
url = 'http://apis.data.go.kr/B552061/jaywalking/getRestJaywalking?ServiceKey=8T4gah%2BS5QQySXPszuE5cLNz7xPRwaPHKzOA5KJOeSXPffbPpF0%2F1YpgrsV8DDqgRLFtDz7HCYpalWfxopnwwg%3D%3D&searchYearCd=2014&siDo=28&guGun=260&numOfRows=10&pageNo=1'
res = requests.get(url)
text = res.text
print(text)

# soup = BeautifulSoup(text, 'lxml-xml')

# items = soup.select('response > body > items > item')
# l = []

# for item in items:
#     print(item.select_one('spot_nm').text,
#          item.select_one('geom_json').text)
#     store.append([item.select_one('spot_nm').text, 
#               item.select_one('geom_json').text])


# df = pd.DataFrame(l, columns = ['Location', 'xy'])

# df.to_csv('C:/PYTHON/api_test.csv', index=False, encoding='cp949')
# Out:
# <response>
#     <header>
#         <resultCode>00</resultCode>
#         <resultMsg>NORMAL_CODE</resultMsg>
#     </header>
#     <body>
#         <items>
#             <item>
#                 <afos_fid>6103821</afos_fid>
#                 <afos_id>2015052</afos_id>
#                 <bjd_cd>2826011200</bjd_cd>
#                 <spot_cd>230628001</spot_cd>
#                 <sido_sgg_nm>인천 인천서부1</sido_sgg_nm>
#                 <spot_nm>인천광역시 서구 가좌동(건지사거리 부근)</spot_nm>
#                 <occrrnc_cnt>5</occrrnc_cnt>
#                 <caslt_cnt>6</caslt_cnt>
#                 <dth_dnv_cnt>0</dth_dnv_cnt>
#                 <se_dnv_cnt>2</se_dnv_cnt>
#                 <sl_dnv_cnt>4</sl_dnv_cnt>
#                 <wnd_dnv_cnt>0</wnd_dnv_cnt>
# ...

# %%
store1 = []

# %%
df1 = pd.DataFrame(store1, columns = ['Location', 'count', 'LONG','LATI'])

df1.to_csv('C:/PYTHON/2014~2017.csv', index=False, encoding='cp949')
